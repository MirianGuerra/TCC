# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Funçoes

def unicos(df, coluna):
    return df[coluna].unique()

# %%
df_nacionalidade_2021_2 = pd.read_csv('Estrangeiros_por_nacionalidade_2021_2.csv', sep=';', encoding='latin-1')
df_nacionalidade_2022_1 = pd.read_csv('Estrangeiros_por_nacionalidade_2022_1.csv', sep=';', encoding='latin-1')
dic = pd.read_csv('DIC_Quantidade_de_alunos_estrangeiros_por_nacionalidade.csv', sep=';', encoding='latin-1')
vw_2019=  pd.read_csv('VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_20190517.csv', sep=';', encoding='latin-1')


vw_2019
# Out:
#              ï»¿NOMEDEP              DE               DISTR  \
# 0     ESTADUAL - OUTROS  CAMPINAS LESTE      CAMPINAS LESTE
# 1     ESTADUAL - OUTROS    CENTRO OESTE      RAPOSO TAVARES
# 2     ESTADUAL - OUTROS      CENTRO SUL          BELA VISTA
# 3     ESTADUAL - OUTROS        SOROCABA            SOROCABA
# 4     ESTADUAL - OUTROS         TAUBATE            CACAPAVA
# ...                 ...             ...                 ...
# 9005            PRIVADA         TAUBATE            CACAPAVA
# 9006            PRIVADA         TAUBATE             TAUBATE
# 9007            PRIVADA      VOTORANTIM  ARACOIABA DA SERRA
# 9008            PRIVADA      VOTORANTIM      CAPELA DO ALTO
# 9009            PRIVADA      VOTORANTIM          VOTORANTIM
#
#                      MUN  TIPOESC  COD_ESC  \
# 0               CAMPINAS       27    45949
# 1              SAO PAULO       11   438820
# 2              SAO PAULO       11   299364
# 3               SOROCABA       11    16354
# ...

# %%
unicos(df_nacionalidade_2021_2,'NOMEDEP')
# Out:
# array(['ESTADUAL - SE', 'MUNICIPAL', 'PRIVADA', 'FEDERAL',
#        'ESTADUAL - OUTROS'], dtype=object)

# %%
dic
# Out:
#   ï»¿Nome do Campo     DescriÃ§Ã£o do Campo       Tipo do Dado
# 0          nomedep           Rede de Ensino              Texto
# 1               de              Nome da DER              Texto
# 2            distr                 Distrito              Texto
# 3              mun               MunicÃ­pio              Texto
# 4          tipoesc           Tipo da Escola  NumÃ©rico Inteiro
# 5          cod_esc        CÃ³digo da Escola  NumÃ©rico Inteiro
# 6           nomesc  Nome da Unidade Escolar              Texto
# 7          DS_PAIS          PaÃ­s de Origem              Texto
# 8       NÂº alunos        NÃºmero de alunos  NumÃ©rico Inteiro
